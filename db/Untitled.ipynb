# %%
import io
import json
import os
import sys
import pandas as pd
from bs4 import BeautifulSoup as bs

import requests
from requests.sessions import Session

import numpy as np
from scipy import stats
import datetime
import time
import statistics as st
import concurrent
from threading import Thread,local
import asyncio
import aiohttp
import tqdm
import nest_asyncio
import re

nest_asyncio.apply()

# %%
headers = {
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en-US,en;q=0.8',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
}

class DataError(ValueError): pass
class PMUError(Exception): pass

class Partants_scrapper():
    def __init__(self, course, training=True):
        self.course = course
        self.courseId = course["id"]
        self.date = course["date"].strftime("%Y-%m-%d")
        self.idHippo = course["idHippo"]
        self.numCourse = course["numCourse"]
        self.numReunion = course["numReunion"]
        self.heure = course["heureCourse"]
        self.has_tracking = course["hasTracking"]
        self.r_tab_partant = None
        self.r_tab_arrivee = None
        self.r_partant_pmu = None
        
        self.distance = course["distance"]
        self.categorie = course["categorie"].split(" ")[1]
        
        self.training = training
        self.classement = None
        self.gains = None
        
        try:
            loop = asyncio.get_event_loop()
            programme = loop.run_until_complete(asyncio.gather(self._info_tableau_partant()))

            df = pd.DataFrame(programme[0])
            df["rid"] = df["id"]
            df.drop('id', inplace=True, axis=1)
            if 'tauxReclamation' in list(df):
                df.drop('tauxReclamation', inplace=True, axis=1)
                
            if 'commentaireApresCourse_texte' in list(df):
                df.drop('commentaireApresCourse_texte', inplace=True, axis=1)   
            if 'commentaireApresCourse_source' in list(df):
                df.drop('commentaireApresCourse_source', inplace=True, axis=1)
            if 'handicapPoids' in list(df):
                df.drop('handicapPoids', inplace=True, axis=1) 
            if 'nomPereMere' in list(df):
                df.drop('nomPereMere', inplace=True, axis=1)
            self.info_partants = df.to_dict('records')
        except Exception as e:
            self.info_partants = None
            
    def _reduc_to_sec(self,reduc):
        minutes = int(reduc[0])
        secondes = int(reduc[1:3])
        dixieme = int(reduc[3])
        return (60  * minutes + secondes + dixieme/10)*1000
        
        
    async def _request_tableau_partants(self, session):
        async with session.get(f"https://www.letrot.com/stats/fiche-course/{self.date}/{self.idHippo}/{self.numCourse}/partants/tableau", headers=headers) as response:
             r = await response.text()
        soup = bs(r, "html.parser")
        headers_table = soup.find("table", {"id": "result_table"}).find("thead").find("tr").find_all("th")
        table = soup.find("table", {"id": "result_table"}).find("tbody")
        rows = table.find_all("tr")
        self.r_tab_partant = rows, headers_table
    
    async def _request_tableau_arrive(self, session):
        async with session.get(f"https://www.letrot.com/stats/fiche-course/{self.date}/{self.idHippo}/{self.numCourse}/resultats/arrivee-definitive", headers=headers) as response:
             r = await response.text()
        soup = bs(r, "html.parser")
        headers_table = soup.find("table", {"id": "result_table"}).find("thead").find("tr").find_all("th")
        table = soup.find("table", {"id": "result_table"}).find("tbody")
        rows = table.find_all("tr")
        
        classement = {row.select("td")[1].text : row.select("td")[0].find("span", {"class": "bold"}).text for row in rows}
        gains = {row.select("td")[1].text : row.find("div", {"class": "gains"}).text.replace(" ", "").replace("€", "") for row in rows}
        self.classement = classement
        self.gains = gains
        self.r_tab_arrivee = rows,classement
        
    async def _request_tableau_tracking(self, session):
        async with session.get(f"https://www.letrot.com/stats/fiche-course/{self.date}/{self.idHippo}/{self.numCourse}/tracking", headers=headers) as response:
             r = await response.text()
        soup = bs(r, "html.parser")
        headers_table = soup.find("table", {"id": "result_table"}).find("thead").find("tr").find_all("th")
        table = soup.find("table", {"id": "result_table"}).find("tbody")
        rows = table.find_all("tr")
        
        tracking = []
        for r in rows:
            cheval = {}
            cheval["num_tracking"] = int(r.find("td", {"title": "Numéro"}).text)
            cheval["distPremArriv"] = int(r.find("td", {"title": "Distance par rapport au 1er à l'arrivée en mètres"}).span.text)
            cheval["reduc2000m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km aux 2 000 m"}).span.text)
            cheval["class2000m"] = int(r.find("td", {"title": "Classement aux 2 000 m"}).span.text)
            
            cheval["reduc1500m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km aux 1 500 m"}).span.text)
            cheval["class1500m"] = int(r.find("td", {"title": "Classement aux 1 500 m"}).span.text)
            
            cheval["reduc1000m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km aux 1 000 m"}).span.text)
            cheval["class1000m"] = int(r.find("td", {"title": "Classement aux 1 000 m"}).span.text)   
            
            cheval["reduc500m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km aux 500 m"}).span.text)
            cheval["class500m"] = int(r.find("td", {"title": "Classement aux 500 m"}).span.text)
            
            cheval["reducLast1000m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km derniers 1000 m"}).span.text)
            cheval["reducLast500m"] = self._reduc_to_sec(r.find("td", {"title": "Réduction km derniers 500 m"}).span.text)
            
            tracking.append(cheval)
            
        tracking.sort(key=lambda x: x["num_tracking"])
        
        self.tracking = tracking
    
    async def _request_partant_pmu(self, session):
        date_pmu = "".join(self.date.split("-")[::-1]) 
        async with session.get(f"https://online.turfinfo.api.pmu.fr/rest/client/65/programme/{date_pmu}/R{self.numReunion}/C{self.numCourse}/participants", headers=headers) as response:
             participants_pmu = await response.json()
        try:
            pmu_jsoned = participants_pmu["participants"]
            participants = pd.json_normalize(pmu_jsoned, sep="_").to_dict(orient="records")
            participants_with_id = [dict(item, **{"id": self.courseId, "numReunion": self.numReunion}) for item in participants]  
            self.r_partant_pmu = participants_with_id
        except:
            raise PMUError("Erreur API PMU")
            
        
        
    async def _info_tableau_partant(self):
        chevaux = []
        
        tasks = []
        async with aiohttp.ClientSession() as session:
            tasks.append(asyncio.ensure_future(self._request_tableau_partants(session)))
            tasks.append(asyncio.ensure_future(self._request_tableau_arrive(session)))
            tasks.append(asyncio.ensure_future(self._request_partant_pmu(session)))
#             tasks.append(asyncio.ensure_future(self.get_info_couple(session)))
#             tasks.append(asyncio.ensure_future(self.get_info_cheval_hippo(session)))
            if self.has_tracking:
                tasks.append(asyncio.ensure_future(self._request_tableau_tracking(session)))
            res = await asyncio.gather(*tasks, return_exceptions=True)
            
        for r in res:
            if type(r) == PMUError:
                raise PMUError("Erreur PMU")
       
        try:
            tableau_partants, headers_table = self.r_tab_partant
            tableau_arrivee,classement = self.r_tab_arrivee
            tableau_pmu = self.r_partant_pmu
        except:
            raise DataError("Erreur donnée")
        
        chevaux.extend(tableau_pmu)
        
        for i,row in enumerate(tableau_partants):
                num = row.select("td")[0].find("span", {"class": "bold"}).text
                col = row.select("td")
                cheval = {}
                cheval["num"] = num
                cheval["nom"] = col[1].text
                
                if self.has_tracking and int(num) == self.tracking[i]["num_tracking"] and len(self.tracking) == len(tableau_partants):
                    cheval.update(self.tracking[i])
                
                cheval["numCoursePMU"] = f"R{self.numReunion}C{self.numCourse}"

                if self.training:
                    if num == "NP":
                        cheval["classement"] = "NP"
                    else:
                        cheval["classement"] = classement[num]
                      
                if num != "NP":
                    cheval["gainCourse"] = int(self.gains[num])
                else:
                    cheval["gainCourse"] = 0
                    
                cheval["id"] = self.courseId
                cheval["date"] = self.date
                cheval["url"] = col[1].find("a").get("href")

                cheval["heureCourse"] = self.heure
                cheval["fer"] = int(col[3].text) if col[3].text else 0
                cheval["firstTimeFer"] = 1 if col[3].find("div", {"class", "fer-first-time"}) else 0
                cheval["sex"] = 0 if col[4].text == "M" else 1
                cheval["age"] = int(col[5].text)
                cheval["dist"] = int(col[6].text.replace(" ", "").replace("\n", ""))
                cheval["driver"] = col[7].find("a").get("href")
                cheval["trainer"] = col[8].find("a").get("href")
                
                cheval["driver_id"] = cheval["driver"].split("/")[-3]
                cheval["trainer_id"] = cheval["trainer"].split("/")[-3]

                if "Avis" in headers_table[9].text:
                    cheval["avisTrainer"] = int(col[9].get("data-order"))
                    avis = col.pop(9)
                    col.insert(-1, avis)
                else:
                    cheval["avisTrainer"] = 2
                
                music = list(filter(lambda x: "a" in x, col[9].text.replace("D", "0").replace("Ret", "0").replace("T", "0").split()))

                try:
                    cheval["recordAbs"] = list(map(int, col[10].text.replace(col[10].span.text, "").replace("\'", '"').split('"')))
                    cheval["recordAbs"] = cheval["recordAbs"][0] * 10 * 60 + cheval["recordAbs"][1] * 10 + cheval["recordAbs"][2]
                except:
                    cheval["recordAbs"] = None

                cheval["gain"] = int(col[11].find("div", class_="gains").text.replace(" ", "")[:-1])
                
                chevaux[i].update(cheval)
        return chevaux
    
    
    async def get_tracking(self,session, url):
        async with session.get(url.replace("dernieres-performances", "tracking"), headers=headers) as response:
             r = await response.text()
        soup = bs(r, "html.parser")
        headers_table = soup.find("table", {"id": "result_table"}).find("thead").find("tr").find_all("th")
        table = soup.find("table", {"id": "result_table"}).find("tbody")
        rows = table.find_all("tr")
        
        info_tracking = {}
        
        distance_au_premier_arrivee = []
        accélération_500m = []
        gain_classement_500m = []
        for row in rows:
            dist_prem = int(row.find_all("td")[2].span.text)
            if dist_prem < 9999:
                distance_au_premier_arrivee.append(dist_prem)
            
            pre_fin = int(row.find_all("td")[17].span.text)
            fin = int(row.find_all("td")[18].span.text)
            if pre_fin < 2000 and fin < 2000:                                            
                accélération_500m.append(pre_fin - fin)
                

            try:
                class_500m = int(row.find_all("td")[16].span.text)
                class_final = int(row.find_all("td")[1].find("span", {"class": "bold"}).text)
                if class_500m -  class_final < 10:
                    gain_classement_500m.append(class_500m -  class_final)
            except:
                gain_classement_500m.append(0)
            
        info_tracking["mean_dist_arrivee"] = np.mean(distance_au_premier_arrivee) if len(distance_au_premier_arrivee) > 0 else np.nan
        info_tracking["acceleration_500m"] = np.mean(accélération_500m) if len(accélération_500m) > 0 else np.nan
        info_tracking["gain_classement_fin"] = np.mean(gain_classement_500m) if len(gain_classement_500m) > 0 else np.nan
        return info_tracking

# %%
courses_df = pd.read_csv("../data/courses1922.csv", index_col=0)
courses_df["distance"] = courses_df["distance"].str.replace(" ", "").astype(int)
courses_df["date"] = courses_df["date"] + " " + courses_df["heureCourse"]
courses_df["date"] = pd.to_datetime(courses_df["date"])
courses_df.head()
# Out:
#                  date             id  numReunion hippodrome  idHippo  \
# 0 2019-01-01 14:02:00  2019010175001           1  VINCENNES     7500
# 1 2019-01-01 14:36:00  2019010175002           1  VINCENNES     7500
# 2 2019-01-01 15:15:00  2019010175003           1  VINCENNES     7500
# 3 2019-01-01 15:52:00  2019010175004           1  VINCENNES     7500
# 4 2019-01-01 16:25:00  2019010175005           1  VINCENNES     7500
#
#   heureCourse discipline  numCourse                    prix allocation  \
# 0       14:02     Attelé          1      PRIX DE PITHIVIERS     47 000
# 1       14:36     Attelé          2      PRIX PIERRE RAFFRE     35 000
# 2       15:15     Attelé          3  PRIX DU CROISE-LAROCHE     54 000
# 3       15:52     Attelé          4     PRIX DE CHARLEVILLE     39 000
# 4       16:25     Attelé          5        PRIX D'ANGOULEME     63 000
#
#    distance categorie typePiste  \
# 0      2700  Course B       NaN
# 1      2850  Course D       NaN
# 2      2850  Course C       NaN
# 3      2100  Course D       NaN
# 4      2100  Course A       NaN
#
#                                 conditionsEngagement  hasTracking  \
# 0  Pour pouliches de 4 ans (F), n'ayant pas gagné...         True
# 1  Course D<br />Pour chevaux entiers et hongres ...        False
# 2  Pour 8 et 9 ans (B et A), n'ayant pas gagné 23...         True
# 3  Course Européenne<br />Départ à l'autostart<br...        False
# 4  Course Européenne<br />Départ à l'autostart<br...         True
#
#    hasVideoHeat  statut             classement  \
# 0         False      16     5 - 11 - 3 - 8 - 4
# 1         False      16      4 - 5 - 9 - 3 - 7
# 2         False      16  11 - 2 - 13 - 15 - 14
# 3         False      16    6 - 1 - 11 - 9 - 12
# 4         False      16    6 - 1 - 12 - 4 - 11
#
#                                             linkPrix  \
# 0  https://www.letrot.com/stats/fiche-course/2019...
# 1  https://www.letrot.com/stats/fiche-course/2019...
# 2  https://www.letrot.com/stats/fiche-course/2019...
# 3  https://www.letrot.com/stats/fiche-course/2019...
# 4  https://www.letrot.com/stats/fiche-course/2019...
#
#                                               replay
# 0  <a href="https://www.letrot.com/fr/replay-cour...
# 1  <a href="https://www.letrot.com/fr/replay-cour...
# 2  <a href="https://www.letrot.com/fr/replay-cour...
# 3  <a href="https://www.letrot.com/fr/replay-cour...
# 4  <a href="https://www.letrot.com/fr/replay-cour...

# %%
testcourses = pd.read_sql("SELECT * FROM courses", con=engine)
testcourses["date"] = pd.to_datetime(testcourses["date"])

# %%
testcourses
# Out:
#                   id                date  numReunion           hippodrome  \
# 0      2022091782013 2022-09-17 15:00:00           6  BEAUMONT DE LOMAGNE
# 1      2022091782015 2022-09-17 16:00:00           6  BEAUMONT DE LOMAGNE
# 2      2022091782016 2022-09-17 16:30:00           6  BEAUMONT DE LOMAGNE
# 3      2022091782017 2022-09-17 17:00:00           6  BEAUMONT DE LOMAGNE
# 4      2022091782018 2022-09-17 17:30:00           6  BEAUMONT DE LOMAGNE
# ...              ...                 ...         ...                  ...
# 12678  2021032014076 2021-03-20 13:42:00           3              LISIEUX
# 12679  2021032151027 2021-03-21 18:30:00           4                REIMS
# 12680  2021032214002 2021-03-22 15:36:00           4                 CAEN
# 12681  2021032214004 2021-03-22 16:36:00           4                 CAEN
# 12682  2021032375026 2021-03-23 18:09:00           4              ENGHIEN
#
#        idHippo heureCourse discipline  numCourse  \
# 0         8201       15:00     Attelé          3
# 1         8201       16:00     Attelé          5
# 2         8201       16:30     Attelé          6
# 3         8201       17:00     Attelé          7
# 4         8201       17:30     Attelé          8
# ...        ...         ...        ...        ...
# 12678     1407       13:42     Attelé          6
# 12679     5102       18:30     Attelé          7
# 12680     1400       15:36     Attelé          2
# 12681     1400       16:36     Attelé          4
# 12682     7502       18:09     Attelé          6
#
#                                            prix allocation  distance  \
# 0                               PRIX D'AVENCHES     16 000      2400
# 1                        PRIX MEADOWLAND (Gr A)     13 000      2400
# 2      PX DE LA COMMUNAUTE DE COMMUNES TARN&GAR     13 000      2400
# 3                               PRIX DE WOLVEGA     20 000      2550
# 4                          PRIX DE GOTEBORG ABY     21 000      2550
# ...                                         ...        ...       ...
# 12678                     PRIX VILLE DE LISIEUX     15 000      2725
# 12679                      PRIX DES PAQUERETTES     16 000      2550
# 12680                        PRIX DE DEMONVILLE     18 000      2450
# 12681                        PRIX DE BENERVILLE     18 000      2200
# 12682                      PRIX DE CHENNEVIERES     18 000      2875
#
#       categorie typePiste                               conditionsEngagement  \
# 0      Course F      None  Départ à l'autostart<br />Pour juments de 5 an...
# 1      Course F      None  Départ à l'autostart<br />Pour 4 ans, n'ayant ...
# 2      Course F      None  Départ à l'autostart<br />Pour 4 ans, n'ayant ...
# 3      Course F      None  Pour 7 et 8 ans, n'ayant pas gagné 124.000. - ...
# 4      Course F      None  Pour 6 à 9 ans inclus, n'ayant pas gagné 149.0...
# ...         ...       ...                                                ...
# 12678  Course F      None  Pour poulains entiers et hongres de 4 ans, n'a...
# 12679  Course F      None         Pour 3 ans, n'ayant pas gagné 5.000.<br />
# 12680  Course E      None  Pour poulains entiers et hongres de 3 ans, n'a...
# 12681  Course E      None  Départ à l'autostart<br />Pour poulains entier...
# 12682  Course R      None  Course "a reclamer"<br />Pour 4 et 5 ans, les ...
#
#        hasTracking  hasVideoHeat  statut            classement  \
# 0                0             0      16   1 - 2 - 12 - 8 - 11
# 1                0             0      16   12 - 6 - 11 - 8 - 2
# 2                0             0      16  8 - 11 - 16 - 1 - 10
# 3                0             0      16   3 - 10 - 6 - 17 - 9
# 4                0             0      16     7 - 8 - 4 - 9 - 1
# ...            ...           ...     ...                   ...
# 12678            0             1      16    4 - 7 - 13 - 6 - 8
# 12679            0             0      16   13 - 6 - 5 - 10 - 9
# 12680            0             0      16    2 - 7 - 9 - 8 - 10
# 12681            0             1      16     3 - 7 - 5 - 6 - 1
# 12682            1             0      16  8 - 14 - 13 - 9 - 10
#
#                                                 linkPrix  \
# 0      https://www.letrot.com/stats/fiche-course/2022...
# 1      https://www.letrot.com/stats/fiche-course/2022...
# 2      https://www.letrot.com/stats/fiche-course/2022...
# 3      https://www.letrot.com/stats/fiche-course/2022...
# 4      https://www.letrot.com/stats/fiche-course/2022...
# ...                                                  ...
# 12678  https://www.letrot.com/stats/fiche-course/2021...
# 12679  https://www.letrot.com/stats/fiche-course/2021...
# 12680  https://www.letrot.com/stats/fiche-course/2021...
# 12681  https://www.letrot.com/stats/fiche-course/2021...
# 12682  https://www.letrot.com/stats/fiche-course/2021...
#
#                                                   replay
# 0      <a href="https://www.letrot.com/fr/replay-cour...
# 1      <a href="https://www.letrot.com/fr/replay-cour...
# 2      <a href="https://www.letrot.com/fr/replay-cour...
# 3      <a href="https://www.letrot.com/fr/replay-cour...
# 4      <a href="https://www.letrot.com/fr/replay-cour...
# ...                                                  ...
# 12678  <a href="https://www.letrot.com/fr/replay-cour...
# 12679  <a href="https://www.letrot.com/fr/replay-cour...
# 12680  <a href="https://www.letrot.com/fr/replay-cour...
# 12681  <a href="https://www.letrot.com/fr/replay-cour...
# 12682  <a href="https://www.letrot.com/fr/replay-cour...
#
# [12683 rows x 20 columns]

# %%
info_2 = []
t = time.time()
counter = 0

def gen_rows(df):
    for row in df.itertuples(index=False):
        yield row._asdict()
# ids = pd.read_csv("data/final_data_2122.csv").id.unique()
# c_filtered = c.loc[~c.id.isin(ids)]

for row in gen_rows(courses_df[~courses_df["id"].astype(str).isin(courses_saved.id.unique())]):
    res = Partants_scrapper(row)
    if isinstance(res.info_partants, list):
        try:
            with Session(engine) as session:
                partants = [Partant(**i) for i in res.info_partants]
                courses = [Course(**row, partants=partants)]
                session.add_all(courses)
                session.commit()
        except Exception as e:
            print(e)
            continue
#         info_2.extend(res.info_partants)
#         pd.DataFrame(res.info_partants).to_csv("data/final_data_2122.csv",mode="a", header=not os.path.isfile("data/final_data_2122.csv") ,index=False)
tps = time.time() - t
print(f"Fini en {int(tps//60)}min {int(tps%60)}s")
# Out:
# 'handicapPoids' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# 'commentaireApresCourse_source' is an invalid keyword argument for Partant
# Fini en 28min 32s

# %%
df = pd.DataFrame(info_2)
df["gainCourse"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4       400
# 5      1600
# 6         0
# 7       200
# 8         0
# 9         0
# 10     1000
# 11        0
# 12        0
# 13     2800
# 14     5000
# 15     9000
# 16        0
# 17        0
# 18     1150
# 19      230
# 20        0
# 21        0
# 22        0
# 23        0
# 24    10350
# 25     1840
# 26        0
# 27      460
# 28        0
# 29        0
# 30     3220
# 31        0
# 32     5750
# 33        0
# 34        0
# 35      200
# 36     2800
# 37     1000
# 38     9000
# 39        0
# 40     5000
# 41        0
# 42      400
# 43     1600
# 44        0
# Name: gainCourse, dtype: int64

# %%
list(test)
# Out:
# ['id',
#  'nom',
#  'numPmu',
#  'age',
#  'sexe',
#  'race',
#  'statut',
#  'placeCorde',
#  'oeilleres',
#  'proprietaire',
#  'entraineur',
#  'driver',
#  'driverChange',
#  'indicateurInedit',
#  'musique',
#  'nombreCourses',
#  'nombreVictoires',
#  'nombrePlaces',
#  'nomPere',
#  'nomMere',
#  'ordreArrivee',
#  'jumentPleine',
#  'engagement',
#  'supplement',
#  'handicapDistance',
#  'poidsConditionMonteChange',
#  'tempsObtenu',
#  'reductionKilometrique',
#  'allure',
#  'robe_code',
#  'robe_libelleCourt',
#  'robe_libelleLong',
#  'dernierRapportDirect_typePari',
#  'dernierRapportDirect_rapport',
#  'dernierRapportDirect_typeRapport',
#  'dernierRapportDirect_indicateurTendance',
#  'dernierRapportDirect_nombreIndicateurTendance',
#  'dernierRapportDirect_dateRapport',
#  'dernierRapportDirect_permutation',
#  'dernierRapportDirect_favoris',
#  'dernierRapportDirect_numPmu1',
#  'dernierRapportDirect_grossePrise',
#  'deferre',
#  'dernierRapportReference_typePari',
#  'dernierRapportReference_rapport',
#  'dernierRapportReference_typeRapport',
#  'dernierRapportReference_indicateurTendance',
#  'dernierRapportReference_nombreIndicateurTendance',
#  'dernierRapportReference_dateRapport',
#  'dernierRapportReference_permutation',
#  'dernierRapportReference_favoris',
#  'dernierRapportReference_numPmu1',
#  'dernierRapportReference_grossePrise',
#  'incident',
#  'numReunion',
#  'num',
#  'numCoursePMU',
#  'classement',
#  'date',
#  'url',
#  'heureCourse',
#  'fer',
#  'firstTimeFer',
#  'sex',
#  'dist',
#  'trainer',
#  'driver_id',
#  'trainer_id',
#  'avisTrainer',
#  'recordAbs',
#  'gain',
#  'rid',
#  'ecurie',
#  'urlCasaque',
#  'nombrePlacesSecond',
#  'nombrePlacesTroisieme',
#  'eleveur',
#  'avisEntraineur',
#  'gainsParticipant_gainsCarriere',
#  'gainsParticipant_gainsVictoires',
#  'gainsParticipant_gainsPlace',
#  'gainsParticipant_gainsAnneeEnCours',
#  'gainsParticipant_gainsAnneePrecedente',
#  'poidsConditionMonte',
#  'num_tracking',
#  'distPremArriv',
#  'reduc2000m',
#  'class2000m',
#  'reduc1500m',
#  'class1500m',
#  'reduc1000m',
#  'class1000m',
#  'reduc500m',
#  'class500m',
#  'reducLast1000m',
#  'reducLast500m',
#  'race_id']

# %%
test = pd.read_sql("SELECT * FROM partants WHERE date BETWEEN '2021-01-01' AND '2021-12-22' ORDER BY date", con=engine)
test["date"] = pd.to_datetime(test["date"])
test.sort_values(["date","rid","numPmu"], inplace=True)
test.reset_index(drop=True, inplace=True)
# test["accel500m"] = (test["reducLast1000m"] - test["reducLast500m"])
test[["rid","nom","classement","gainCourse"]].tail()
# Out:
#                  rid               nom classement  gainCourse
# 54038  2021122275008        IMPRESSION          7         380
# 54039  2021122275008     ISABELLA FERM          3        5320
# 54040  2021122275008    ILE AUX MOINES          2        9500
# 54041  2021122275008  IRONIE D'HERIPRE          0           0
# 54042  2021122275008     INES DE BLARY          1       17100

# %%
test["driver_id"]
# Out:
# 0        Y2N3YwEFYA
# 1        Y2RbZwoAfw
# 2        Z2t8YQAFdw
# 3        YGJaZQMFYQ
# 4        Y2J6YwUDdw
#             ...
# 54038    Z2JbZgIAeg
# 54039    Z2Z6ZwECfA
# 54040    YGJaZwQFZA
# 54041    bGN6YAUIeQ
# 54042    ZGtaZAQCdA
# Name: driver_id, Length: 54043, dtype: object

# %%
test["lastRace"] = test.groupby("nom")["date"].transform(lambda x: x - x.shift(1))
test["lastRace_driver"] = test.groupby("driver_id")["date"].transform(lambda x: x - x.shift(1))

# %%
test["classLastRace_horse"] = test.groupby("nom")["classement"].transform(lambda x: x.shift(1))
test["classLastRace_driver"] = test.groupby("driver_id")["classement"].transform(lambda x: x.shift(1))

# %%
test[["date","nom","lastRace","classement","classLastRace"]].tail(20)
# Out:
#             date                 nom lastRace classement classLastRace
# 54023 2021-12-22    FOLIE DE HOUELLE  10 days          9             0
# 54024 2021-12-22       FERIA DU METZ  16 days         DA             2
# 54025 2021-12-22        FLORA VENESI  16 days          7            DA
# 54026 2021-12-22    FABULEUSE FLIGNY  16 days          0             6
# 54027 2021-12-22       FEE DE LUNOJO  23 days          3             3
# 54028 2021-12-22         ISHTAR FONT  78 days          0             0
# 54029 2021-12-22     IRIS DES CHAMPS  10 days          0            DA
# 54030 2021-12-22    INFANTE D'ERABLE  78 days          8             4
# 54031 2021-12-22        INDEPENDANTE  16 days          9            DA
# 54032 2021-12-22      ILLUSION JIPAD   7 days          6             1
# 54033 2021-12-22  IDYLLE DU CHATAULT  69 days          0            DA
# 54034 2021-12-22   IMPERIALE DE BAIS  16 days          0             6
# 54035 2021-12-22           IPHIGENIA  43 days          0             1
# 54036 2021-12-22     ILLIANA DU CLOS  22 days          5             4
# 54037 2021-12-22   IRINA DE MONTCEAU  10 days          4             3
# 54038 2021-12-22          IMPRESSION  16 days          7             2
# 54039 2021-12-22       ISABELLA FERM  14 days          3             1
# 54040 2021-12-22      ILE AUX MOINES  10 days          2             6
# 54041 2021-12-22    IRONIE D'HERIPRE  22 days          0            DA
# 54042 2021-12-22       INES DE BLARY  66 days          1             4

# %%
groupnom = test.groupby("nom")
test["weightDist"] = np.max((test["gainCourse"].to_numpy(), np.ones(len(test["gainCourse"]))), axis=0)
test["weightDistSum"] = groupnom["weightDist"].transform(lambda x: x.shift(1).rolling(20, min_periods=1).sum())
test["distProd"] = test["weightDist"] * test["dist"]
test["distProdSum"] = groupnom["distProd"].transform(lambda x: x.shift(1).rolling(20, min_periods=1).sum())
test["preferedDist"] =  test["distProdSum"]/test["weightDistSum"] 
test["preferedDist"]
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 54038    2250.772852
# 54039    2200.144732
# 54040    2252.807924
# 54041    2437.500000
# 54042    2354.990720
# Name: preferedDist, Length: 54043, dtype: float64

# %%
groupdriver = test.groupby("driver_id")
test["weightDistSum_driver"] = groupdriver["weightDist"].transform(lambda x: x.shift(1).rolling(50, min_periods=1).sum())
test["distProdSum_driver"] = groupdriver["distProd"].transform(lambda x: x.shift(1).rolling(50, min_periods=1).sum())
test["preferedDist_driver"] =  test["distProdSum_driver"]/test["weightDistSum_driver"] 
test["preferedDist_driver"]
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 54038    2539.471015
# 54039    2609.741765
# 54040    2732.218517
# 54041    2643.606049
# 54042    2426.216316
# Name: preferedDist_driver, Length: 54043, dtype: float64

# %%
test["lastRaceDist"] = groupnom["dist"].transform(lambda x: x.shift(1))

# %%
test[["driver_id"]]
# Out:
#         driver_id
# 0      Y2N3YwEFYA
# 1      Y2RbZwoAfw
# 2      Z2t8YQAFdw
# 3      YGJaZQMFYQ
# 4      Y2J6YwUDdw
# ...           ...
# 54038  Z2JbZgIAeg
# 54039  Z2Z6ZwECfA
# 54040  YGJaZwQFZA
# 54041  bGN6YAUIeQ
# 54042  ZGtaZAQCdA
#
# [54043 rows x 1 columns]

# %%
test.loc[test["driver_id"] == "YWR4bAEEfA"][["date","nom","driver","lastRace_driver","classement","classLastRace","gainCourse","dist","lastRaceDist","preferedDist_driver"]]
# Out:
#             date                nom  \
# 1134  2021-01-11  HADOL DU CHATELET
# 1169  2021-01-11   IVAKIR DU VARLET
# 2417  2021-01-22       HILTON BERRY
# 4128  2021-02-06       EMILE DU VAR
# 6502  2021-02-27      HAPPY DU LION
# ...          ...                ...
# 51020 2021-12-05  IP OP DE LA ROQUE
# 51253 2021-12-06             ITALIE
# 51266 2021-12-06    HEROINE DE PUCH
# 53844 2021-12-21     HOOKER DU PECH
# 53864 2021-12-21   GELINA DE PIQUET
#
#                                                   driver lastRace_driver  \
# 1134   https://www.letrot.com/stats/fiche-homme/david...             NaT
# 1169   https://www.letrot.com/stats/fiche-homme/david...          0 days
# 2417   https://www.letrot.com/stats/fiche-homme/david...         11 days
# 4128   https://www.letrot.com/stats/fiche-homme/david...         15 days
# 6502   https://www.letrot.com/stats/fiche-homme/david...         21 days
# ...                                                  ...             ...
# 51020  https://www.letrot.com/stats/fiche-homme/david...          0 days
# 51253  https://www.letrot.com/stats/fiche-homme/david...          1 days
# 51266  https://www.letrot.com/stats/fiche-homme/david...          0 days
# 53844  https://www.letrot.com/stats/fiche-homme/david...         15 days
# 53864  https://www.letrot.com/stats/fiche-homme/david...          0 days
#
#       classement classLastRace  gainCourse  dist  lastRaceDist  \
# 1134          DA           NaN           0  2850           NaN
# 1169           9           NaN           0  2850           NaN
# 2417          DA           NaN           0  2850           NaN
# 4128           6           NaN         400  2850           NaN
# 6502           9           NaN           0  2400           NaN
# ...          ...           ...         ...   ...           ...
# 51020          6             7         260  2850        2900.0
# 51253          5             2         650  2825        2825.0
# 51266         DA             7           0  2825        2400.0
# 53844         DA             3           0  2400        2725.0
# 53864          6             4         340  2400        2575.0
#
#        preferedDist_driver
# 1134                   NaN
# 1169           2850.000000
# 2417           2850.000000
# 4128           2850.000000
# 6502           2850.000000
# ...                    ...
# 51020          2640.784726
# 51253          2642.376053
# 51266          2645.790846
# 53844          2645.794446
# 53864          2645.785805
#
# [131 rows x 10 columns]

# %%
test["distPremMean"] = test.groupby("nom")["distPremArriv"].transform(lambda x: x.rolling(5, min_periods=1).mean(skipna=True).fillna(method='bfill'))

# %%
test[["nom","date","distPremMean"]]
# Out:
#                       nom       date  distPremMean
# 0          HORATIUS D'ELA 2021-01-01          13.0
# 1             HORSY ROYAL 2021-01-01        9999.0
# 2       HERAKLION DESBOIS 2021-01-01        9999.0
# 3            HACKER LOVER 2021-01-01           5.0
# 4      HIDELTO DE HOUELLE 2021-01-01          11.0
# ...                   ...        ...           ...
# 48857        HAKIRA SCOTT 2021-11-21           NaN
# 48858    HASKIDO THISACLE 2021-11-21           NaN
# 48859    HERMIONE DU PONT 2021-11-21           NaN
# 48860     HASTIG VASTERBO 2021-11-21           NaN
# 48861    HELLO LA GLOBULE 2021-11-21           NaN
#
# [54043 rows x 3 columns]

# %%
test["musique"]
# Out:
# 0            5a5aDa4a1aDa1a1a7a
# 1                  1a1a1aDaDa1a
# 2          0aDa5a3aDa7a3a4a3a9a
# 3        6a7a6aDmDm1m1a(19)2m7a
# 4          Da3a3a4a3a3a3a3aDa4a
#                   ...
# 48857      6aDa6aDa0a0aDa6a3a4a
# 48858      7a0a3a7aDaDa3a2a4a3a
# 48859    5a0aDa7a2aDaDa(20)7a2a
# 48860    Da1aDa1aDa7aDaDa(20)Da
# 48861      4a0a8a6a0a2a6a1a3a6a
# Name: musique, Length: 54043, dtype: object

# %%
def parse_musique(mus):
    res = re.findall(r'([0-9D])a',mus)
    res = list(map(lambda x: int(x.replace("0", "10").replace("D", "10")), res))
    if len(res) >0:
        return res
    else:
        return [0]

# %%
test["meanMusic"] = test["musique"].apply(lambda x: np.mean(parse_musique(x)))
test["medianMusic"] = test["musique"].apply(lambda x: np.median(parse_musique(x)))
test["minMusic"] = test["musique"].apply(lambda x: np.min(parse_musique(x)))

# %%
test[["meanMusic","medianMusic","minMusic"]]
# Out:
#        meanMusic  medianMusic  minMusic
# 0       4.888889          5.0         1
# 1       4.000000          1.0         1
# 2       6.400000          6.0         3
# 3       5.400000          6.0         1
# 4       4.600000          3.0         3
# ...          ...          ...       ...
# 48857   7.500000          8.0         3
# 48858   5.900000          5.5         2
# 48859   7.000000          7.0         2
# 48860   7.666667         10.0         1
# 48861   5.600000          6.0         1
#
# [54043 rows x 3 columns]

# %%
parse_musique("4a0a8a6a0a2a6a1a3a6a")
# Out:
# [4, 10, 8, 6, 10, 2, 6, 1, 3, 6]
# (5.6, 6.0, 1)

# %%
test["musique"].apply(parse_musique).to_numpy()
# Out:
# array([list([4.888888888888889, 5.0, 1]), list([4.0, 1.0, 1]),
#        list([6.4, 6.0, 3]), ..., list([7.0, 7.0, 2]),
#        list([7.666666666666667, 10.0, 1]), list([5.6, 6.0, 1])],
#       dtype=object)

# %%
test["distPremArriv"].replace(9999.0, np.nan, inplace=True)

# %%
courses_saved = pd.read_sql("SELECT * FROM courses", con=engine)

# %%
len(courses_df) - len(courses_saved)
# Out:
# 2465

# %%
courses_df[~courses_df["id"].astype(str).isin(courses_saved.id.unique())]
# Out:
#                      date             id  numReunion       hippodrome  \
# 0     2019-01-01 14:02:00  2019010175001           1        VINCENNES
# 9     2019-01-02 15:12:00  2019010275007           2        VINCENNES
# 39    2019-01-06 15:15:00  2019010675004           1        VINCENNES
# 40    2019-01-06 16:31:00  2019010675006           1        VINCENNES
# 43    2019-01-07 13:45:00  2019010775001           1        VINCENNES
# ...                   ...            ...         ...              ...
# 18330 2022-12-22 12:52:00  2022122253073           4  MESLAY-DU-MAINE
# 18331 2022-12-22 13:25:00  2022122253074           4  MESLAY-DU-MAINE
# 18332 2022-12-22 14:46:00  2022122253076           4  MESLAY-DU-MAINE
# 18333 2022-12-22 15:22:00  2022122253077           4  MESLAY-DU-MAINE
# 18334 2022-12-22 15:55:00  2022122253078           4  MESLAY-DU-MAINE
#
#        idHippo heureCourse discipline  numCourse  \
# 0         7500       14:02     Attelé          1
# 9         7500       15:12     Attelé          7
# 39        7500       15:15     Attelé          4
# 40        7500       16:31     Attelé          6
# 43        7500       13:45     Attelé          1
# ...        ...         ...        ...        ...
# 18330     5307       12:52     Attelé          3
# 18331     5307       13:25     Attelé          4
# 18332     5307       14:46     Attelé          6
# 18333     5307       15:22     Attelé          7
# 18334     5307       15:55     Attelé          8
#
#                                    prix allocation  distance categorie  \
# 0                    PRIX DE PITHIVIERS     47 000      2700  Course B
# 9                         PRIX D'ACIGNE     29 000      2175  Course D
# 39     PRIX LE PARISIEN (PRIX DE LILLE)     75 000      2100  Course A
# 40                 PRIX DE VIC SUR CERE     63 000      2850  Course A
# 43                    PRIX DE L'AVEYRON     54 000      2850  Course C
# ...                                 ...        ...       ...       ...
# 18330                  PRIX DES CADEAUX     20 000      2600  Course F
# 18331                  PRIX DE LA NEIGE     20 000      2600  Course F
# 18332               PRIX DES GUIRLANDES     17 000      2875  Course F
# 18333                      PRIX DE NOEL     22 000      2875  Course E
# 18334                       PRIX COULON     33 000      2600  Course D
#
#       typePiste                               conditionsEngagement  \
# 0           NaN  Pour pouliches de 4 ans (F), n'ayant pas gagné...
# 9           NaN  Pour pouliches de 3 ans (G), n'ayant pas gagné...
# 39          NaN  Course Européenne<br />Départ à l'autostart<br...
# 40          NaN  Course Européenne<br />Pour chevaux entiers et...
# 43          NaN  Pour juments de 7, 8 et 9 ans (C, B et A), n'a...
# ...         ...                                                ...
# 18330       NaN  Départ à l'autostart<br />Pour juments de 5 an...
# 18331       NaN  Départ à l'autostart<br />Pour chevaux entiers...
# 18332       NaN         Pour 3 ans, n'ayant pas gagné 9.400.<br />
# 18333       NaN  Pour 6 ans, n'ayant pas gagné 114.000. - Recul...
# 18334       NaN  Départ à l'autostart<br />Pour 6 à 10 ans incl...
#
#        hasTracking  hasVideoHeat  statut            classement  \
# 0             True         False      16    5 - 11 - 3 - 8 - 4
# 9             True         False      16  11 - 14 - 8 - 6 - 13
# 39            True         False      16    8 - 5 - 12 - 1 - 6
# 40            True         False      16   11 - 7 - 12 - 3 - 4
# 43            True         False      16    3 - 4 - 2 - 1 - 11
# ...            ...           ...     ...                   ...
# 18330        False         False      16    5 - 8 - 2 - 16 - 3
# 18331        False         False      16    8 - 15 - 7 - 4 - 6
# 18332        False         False      16   14 - 1 - 12 - 7 - 2
# 18333        False         False      16  18 - 5 - 12 - 4 - 14
# 18334        False         False      16     5 - 2 - 8 - 7 - 3
#
#                                                 linkPrix  \
# 0      https://www.letrot.com/stats/fiche-course/2019...
# 9      https://www.letrot.com/stats/fiche-course/2019...
# 39     https://www.letrot.com/stats/fiche-course/2019...
# 40     https://www.letrot.com/stats/fiche-course/2019...
# 43     https://www.letrot.com/stats/fiche-course/2019...
# ...                                                  ...
# 18330  https://www.letrot.com/stats/fiche-course/2022...
# 18331  https://www.letrot.com/stats/fiche-course/2022...
# 18332  https://www.letrot.com/stats/fiche-course/2022...
# 18333  https://www.letrot.com/stats/fiche-course/2022...
# 18334  https://www.letrot.com/stats/fiche-course/2022...
#
#                                                   replay
# 0      <a href="https://www.letrot.com/fr/replay-cour...
# 9      <a href="https://www.letrot.com/fr/replay-cour...
# 39     <a href="https://www.letrot.com/fr/replay-cour...
# 40     <a href="https://www.letrot.com/fr/replay-cour...
# 43     <a href="https://www.letrot.com/fr/replay-cour...
# ...                                                  ...
# 18330  <a href="https://www.letrot.com/fr/replay-cour...
# 18331  <a href="https://www.letrot.com/fr/replay-cour...
# 18332  <a href="https://www.letrot.com/fr/replay-cour...
# 18333  <a href="https://www.letrot.com/fr/replay-cour...
# 18334  <a href="https://www.letrot.com/fr/replay-cour...
#
# [2458 rows x 20 columns]

# %% [markdown]
# # SQL

# %%
from sqlalchemy import create_engine,ForeignKey
from sqlalchemy.orm import declarative_base,relationship
from sqlalchemy import Column, Integer, String, Boolean, BIGINT, TEXT, INT, FLOAT, BOOLEAN
from sqlalchemy.dialects.sqlite import DATETIME
from sqlalchemy.orm import Session
Base = declarative_base()

engine = create_engine("sqlite:///test.sqlite", echo=False)

# %%
# df.to_sql('partants', con=engine)

# %%
class Course(Base):
    __tablename__ = "courses"

#     id = Column(Integer, primary_key=True)
    id = Column(TEXT, primary_key=True)
    date = Column(DATETIME)
    numReunion = Column(INT)
    hippodrome = Column(TEXT)
    idHippo = Column(INT)
    heureCourse = Column(TEXT)
    discipline = Column(TEXT)
    numCourse = Column(INT)
    prix = Column(TEXT)
    allocation = Column(TEXT)
    distance = Column(INT)
    categorie = Column(TEXT)
    typePiste = Column(TEXT)
    conditionsEngagement = Column(TEXT)
    hasTracking = Column(BOOLEAN)
    hasVideoHeat = Column(BOOLEAN)
    statut = Column(INT)
    classement = Column(TEXT)
    linkPrix = Column(TEXT)
    replay = Column(TEXT)
    
    partants = relationship("Partant", order_by=Partant.numPmu, back_populates="course")
    
    def __repr__(self):
        return "<Course(id='%s', date='%s', numReunion='%s', hippodrome='%s')>" % (
            self.id,
            self.date,
            self.numReunion,
            self.hippodrome,
        )

# %%
class Partant(Base):
    __tablename__ = "partants"

    id = Column(Integer, primary_key=True)
    
    rid = Column(INT)
    nom = Column(TEXT)
    numPmu = Column(INT)
    age = Column(INT)
    sexe = Column(TEXT)
    race = Column(TEXT)
    statut = Column(TEXT)
    placeCorde = Column(FLOAT)
    oeilleres = Column(TEXT)
    proprietaire = Column(TEXT)
    entraineur = Column(TEXT)
    driver = Column(TEXT)
    driverChange = Column(BOOLEAN)
    indicateurInedit = Column(BOOLEAN)
    musique = Column(TEXT)
    nombreCourses = Column(INT)
    nombreVictoires = Column(INT)
    nombrePlaces = Column(INT)
    nomPere = Column(TEXT)
    nomMere = Column(TEXT)
    ordreArrivee = Column(FLOAT)
    jumentPleine = Column(BOOLEAN)
    engagement = Column(BOOLEAN)
    supplement = Column(INT)
    handicapDistance = Column(INT)
    poidsConditionMonteChange = Column(BOOLEAN)
    tempsObtenu = Column(FLOAT)
    reductionKilometrique = Column(FLOAT)
    allure = Column(TEXT)
    robe_code = Column(TEXT)
    robe_libelleCourt = Column(TEXT)
    robe_libelleLong = Column(TEXT)
    dernierRapportDirect_typePari = Column(TEXT)
    dernierRapportDirect_rapport = Column(FLOAT)
    dernierRapportDirect_typeRapport = Column(TEXT)
    dernierRapportDirect_indicateurTendance = Column(TEXT)
    dernierRapportDirect_nombreIndicateurTendance = Column(FLOAT)
    dernierRapportDirect_dateRapport = Column(FLOAT)
    dernierRapportDirect_permutation = Column(FLOAT)
    dernierRapportDirect_favoris = Column(TEXT)
    dernierRapportDirect_numPmu1 = Column(FLOAT)
    dernierRapportDirect_grossePrise = Column(TEXT)
    deferre = Column(TEXT)
    dernierRapportReference_typePari = Column(TEXT)
    dernierRapportReference_rapport = Column(FLOAT)
    dernierRapportReference_typeRapport = Column(TEXT)
    dernierRapportReference_indicateurTendance = Column(TEXT)
    dernierRapportReference_nombreIndicateurTendance = Column(FLOAT)
    dernierRapportReference_dateRapport = Column(FLOAT)
    dernierRapportReference_permutation = Column(FLOAT)
    dernierRapportReference_favoris = Column(TEXT)
    dernierRapportReference_numPmu1 = Column(FLOAT)
    dernierRapportReference_grossePrise = Column(TEXT)
    incident = Column(TEXT)
    numReunion = Column(INT)
    num = Column(TEXT)
    numCoursePMU = Column(TEXT)
    classement = Column(TEXT)
    date = Column(TEXT)
    url = Column(TEXT)
    heureCourse = Column(TEXT)
    fer = Column(INT)
    firstTimeFer = Column(INT)
    sex = Column(INT)
    dist = Column(INT)
    trainer = Column(TEXT)
    driver_id = Column(TEXT)
    trainer_id = Column(TEXT)
    avisTrainer = Column(INT)
    recordAbs = Column(FLOAT)
    gain = Column(INT)
    rid = Column(INT)
    ecurie = Column(TEXT)
    urlCasaque = Column(TEXT)
    nombrePlacesSecond = Column(FLOAT)
    nombrePlacesTroisieme = Column(FLOAT)
    eleveur = Column(TEXT)
    avisEntraineur = Column(TEXT)
    gainCourse = Column(INT)
    gainsParticipant_gainsCarriere = Column(FLOAT)
    gainsParticipant_gainsVictoires = Column(FLOAT)
    gainsParticipant_gainsPlace = Column(FLOAT)
    gainsParticipant_gainsAnneeEnCours = Column(FLOAT)
    gainsParticipant_gainsAnneePrecedente = Column(FLOAT)
    poidsConditionMonte = Column(FLOAT)
    num_tracking = Column(FLOAT)
    distPremArriv = Column(FLOAT)
    reduc2000m = Column(FLOAT)
    class2000m = Column(FLOAT)
    reduc1500m = Column(FLOAT)
    class1500m = Column(FLOAT)
    reduc1000m = Column(FLOAT)
    class1000m = Column(FLOAT)
    reduc500m = Column(FLOAT)
    class500m = Column(FLOAT)
    reducLast1000m = Column(FLOAT)
    reducLast500m = Column(FLOAT)
    
    race_id = Column(Integer, ForeignKey("courses.id"))
    course = relationship("Course", back_populates="partants")

    def __repr__(self):
        return "<Partant(id='%s', numReunion='%s', classement='%s')>" % (
            self.course,
            self.numReunion,
            self.classement,
        )

# %%
Base.metadata.create_all(engine)

# %%
# with Session(engine) as session:
#     l_partant = df[df["rid"] == 2022091675001].to_dict("records")
# #     l_courses = courses_df[courses_df["id"] == 2022091675001].to_dict("records")
# #     print(l_courses)
#     partants = [Partant(**i) for i in l_partant]
#     # print(courses[courses["id"] == 2022091675001].to_dict("records")[0])
#     courses = [Course(**courses_df[courses_df["id"] == 2022091675001].to_dict("records")[0], partants=partants)]

#     session.add_all(courses)
#     session.commit()
# Out:
# 2022-12-22 14:52:13,313 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-22 14:52:13,314 INFO sqlalchemy.engine.Engine INSERT INTO courses (id, date, "numReunion", hippodrome, "idHippo", "heureCourse", discipline, "numCourse", prix, allocation, distance, categorie, "typePiste", "conditionsEngagement", "hasTracking", "hasVideoHeat", statut, classement, "linkPrix", replay) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-12-22 14:52:13,315 INFO sqlalchemy.engine.Engine [cached since 316s ago] (2022091675001, '2022-09-16 18:58:00.000000', 1, 'VINCENNES', 7500, '18:58', 'Attelé', 1, 'PRIX LUCRETIA', '39 000', 2100, 'Course D', nan, "Départ à l'autostart<br />Pour pouliches de 4 ans, n'ayant pas gagné 55.000.<br />", 1, 0, 16, '7 - 4 - 10 - 15 - 3', 'https://www.letrot.com/stats/fiche-course/2022-09-16/7500/1/resultats/arrivee-definitive', '<a href="https://www.letrot.com/fr/replay-courses/2022-09-16/7500/1" class="btn" target="_blank"><svg width="8px" height="12px" viewBox="0 0 8 12" ve ... (213 characters truncated) ... rm="translate(4.000000, 6.000000) rotate(90.000000) translate(-4.000000, -6.000000) " points="4 2 10 10 -2 10"></polygon></g></svg>Voir le replay</a>')
# 2022-12-22 14:52:13,316 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# IntegrityError: UNIQUE constraint failed: courses.id
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-466-7c2a39babed9> in <module>
#       8
#       9     session.add_all(courses)
# ---> 10     session.commit()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#    1421                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1422
# -> 1423         self._transaction.commit(_to_root=self.future)
#    1424
#    1425     def prepare(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in commit(self, _to_root)
#     827         self._assert_active(prepared_ok=True)
#     828         if self._state is not PREPARED:
# --> 829             self._prepare_impl()
#     830
#     831         if self._parent is None or self.nested:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _prepare_impl(self)
#     806                 if self.session._is_clean():
#     807                     break
# --> 808                 self.session.flush()
#     809             else:
#     810                 raise exc.FlushError(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in flush(self, objects)
#    3239         try:
#    3240             self._flushing = True
# -> 3241             self._flush(objects)
#    3242         finally:
#    3243             self._flushing = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3379         except:
#    3380             with util.safe_reraise():
# -> 3381                 transaction.rollback(_capture_exception=True)
#    3382
#    3383     def bulk_save_objects(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    3339             self._warn_on_events = True
#    3340             try:
# -> 3341                 flush_context.execute()
#    3342             finally:
#    3343                 self._warn_on_events = False
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self)
#     451         else:
#     452             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 453                 rec.execute(self)
#     454
#     455     def finalize_flush_changes(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self, uow)
#     625     @util.preload_module("sqlalchemy.orm.persistence")
#     626     def execute(self, uow):
# --> 627         util.preloaded.orm_persistence.save_obj(
#     628             self.mapper,
#     629             uow.states_for_mapper_hierarchy(self.mapper, False, False),
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     240         )
#     241
# --> 242         _emit_insert_statements(
#     243             base_mapper,
#     244             uowtransaction,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping)
#    1092             multiparams = [rec[2] for rec in records]
#    1093
# -> 1094             c = connection._execute_20(
#    1095                 statement, multiparams, execution_options=execution_options
#    1096             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_20(self, statement, parameters, execution_options)
#    1518             )
#    1519         else:
# -> 1520             return meth(self, args_10style, kwargs_10style, execution_options)
#    1521
#    1522     def exec_driver_sql(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: courses.id
# [SQL: INSERT INTO courses (id, date, "numReunion", hippodrome, "idHippo", "heureCourse", discipline, "numCourse", prix, allocation, distance, categorie, "typePiste", "conditionsEngagement", "hasTracking", "hasVideoHeat", statut, classement, "linkPrix", replay) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: (2022091675001, '2022-09-16 18:58:00.000000', 1, 'VINCENNES', 7500, '18:58', 'Attelé', 1, 'PRIX LUCRETIA', '39 000', 2100, 'Course D', nan, "Départ à l'autostart<br />Pour pouliches de 4 ans, n'ayant pas gagné 55.000.<br />", 1, 0, 16, '7 - 4 - 10 - 15 - 3', 'https://www.letrot.com/stats/fiche-course/2022-09-16/7500/1/resultats/arrivee-definitive', '<a href="https://www.letrot.com/fr/replay-courses/2022-09-16/7500/1" class="btn" target="_blank"><svg width="8px" height="12px" viewBox="0 0 8 12" ve ... (213 characters truncated) ... rm="translate(4.000000, 6.000000) rotate(90.000000) translate(-4.000000, -6.000000) " points="4 2 10 10 -2 10"></polygon></g></svg>Voir le replay</a>')]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
for i in df[df["id"] == 2022091675001].to_dict("records"):
    print(i)
# Out:
# {'nom': 'INES PICARDE', 'numPmu': 1, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 1.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie J-F. SENET', 'entraineur': 'J.F. SENET', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/jf-senet/bGV5ZwMDeQ/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '0a6aDa0a7a8a1a8a(21)4a', 'nombreCourses': 33, 'nombreVictoires': 1, 'nombrePlaces': 15, 'nombrePlacesSecond': 4, 'nombrePlacesTroisieme': 2, 'nomPere': "ALADIN D'ECAJEUL", 'nomMere': 'SWEET RAINBOW', 'ordreArrivee': 13.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 154490.0, 'reductionKilometrique': 73600.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P1.png', 'eleveur': 'E.A.R.L. Ecurie des TROTTEURS PICARDS', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 4880000, 'gainsParticipant_gainsVictoires': 810000, 'gainsParticipant_gainsPlace': 4070000, 'gainsParticipant_gainsAnneeEnCours': 864000, 'gainsParticipant_gainsAnneePrecedente': 3219000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 68.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 1, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 31.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '-', 'dernierRapportReference_nombreIndicateurTendance': -15.64, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 1, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '1', 'num_tracking': 1, 'distPremArriv': 43, 'reduc2000m': 70100.0, 'class2000m': 8, 'reduc1500m': 67900.0, 'class1500m': 3, 'reduc1000m': 69700.0, 'class1000m': 3, 'reduc500m': 71300.0, 'class500m': 3, 'reducLast1000m': 77500.0, 'reducLast500m': 80200.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ines-picarde/ZWpbZgEEBQEN/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/jf-senet/bGV5ZwMDeQ/entraineur/dernieres-courses', 'driver_id': 'bGV5ZwMDeQ', 'trainer_id': 'bGV5ZwMDeQ', 'avisTrainer': 2, 'recordAbs': 725, 'gain': 48800, 'ecurie': nan, 'incident': nan}
# {'nom': 'INES DE LA ROUVRE', 'numPmu': 2, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 2.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie L.M. DAVID', 'entraineur': 'L.M. DAVID', 'deferre': 'PROTEGE_ANTERIEURS_DEFERRRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/lm-david/ZmRaYwYFdA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '6a2a0aDa9aDaDa2a7a', 'nombreCourses': 21, 'nombreVictoires': 2, 'nombrePlaces': 9, 'nombrePlacesSecond': 2, 'nombrePlacesTroisieme': 2, 'nomPere': 'BRIAC DARK', 'nomMere': "QUIETUDE D'ORIENT", 'ordreArrivee': 7.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 152000.0, 'reductionKilometrique': 72400.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P2.png', 'eleveur': 'M. Alain Michel CHATEL', 'allure': 'TROT', 'avisEntraineur': 'POSITIF', 'robe_code': '001', 'robe_libelleCourt': 'ALEZAN', 'robe_libelleLong': 'ALEZAN', 'gainsParticipant_gainsCarriere': 4868000, 'gainsParticipant_gainsVictoires': 1395000, 'gainsParticipant_gainsPlace': 3473000, 'gainsParticipant_gainsAnneeEnCours': 2067000, 'gainsParticipant_gainsAnneePrecedente': 2561000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 13.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 2, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 11.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 4.46, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 2, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '2', 'num_tracking': 2, 'distPremArriv': 19, 'reduc2000m': 67100.0, 'class2000m': 3, 'reduc1500m': 69100.0, 'class1500m': 8, 'reduc1000m': 70600.0, 'class1000m': 12, 'reduc500m': 71600.0, 'class500m': 9, 'reducLast1000m': 74000.0, 'reducLast500m': 74100.0, 'numCoursePMU': 'R1C1', 'classement': '7', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ines-de-la-rouvre/ZWpbZwAEAwES/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 6, 'firstTimeFer': 1, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/lm-david/ZmRaYwYFdA/entraineur/dernieres-courses', 'driver_id': 'ZmRaYwYFdA', 'trainer_id': 'ZmRaYwYFdA', 'avisTrainer': 1, 'recordAbs': 731, 'gain': 48680, 'ecurie': nan, 'incident': nan}
# {'nom': 'ICE QUICK', 'numPmu': 3, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 3.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie QUICK STAR', 'entraineur': 'P.J. CORDEAU', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/f-nivard/Y2J6YwUDdw/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '1a3aDa6a1a8a3a7a6aDa', 'nombreCourses': 21, 'nombreVictoires': 3, 'nombrePlaces': 11, 'nombrePlacesSecond': 2, 'nombrePlacesTroisieme': 2, 'nomPere': 'UNIQUE QUICK', 'nomMere': 'BUBBLE QUICK', 'ordreArrivee': 5.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 151740.0, 'reductionKilometrique': 72300.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P3.png', 'eleveur': 'Ecurie QUICK STAR', 'allure': 'TROT', 'avisEntraineur': 'POSITIF', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 5131000, 'gainsParticipant_gainsVictoires': 3195000, 'gainsParticipant_gainsPlace': 1936000, 'gainsParticipant_gainsAnneeEnCours': 3474000, 'gainsParticipant_gainsAnneePrecedente': 1657000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 3.5, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': True, 'dernierRapportDirect_numPmu1': 3, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 3.7, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': ' ', 'dernierRapportReference_nombreIndicateurTendance': 0.0, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': True, 'dernierRapportReference_numPmu1': 3, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '3', 'num_tracking': 3, 'distPremArriv': 16, 'reduc2000m': 69100.0, 'class2000m': 7, 'reduc1500m': 69500.0, 'class1500m': 10, 'reduc1000m': 70300.0, 'class1000m': 8, 'reduc500m': 71500.0, 'class500m': 7, 'reducLast1000m': 74100.0, 'reducLast500m': 73900.0, 'numCoursePMU': 'R1C1', 'classement': '5', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ice-quick/ZWpbZwUJAgcY/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/pj-cordeau/ZmF6bQUAeQ/entraineur/dernieres-courses', 'driver_id': 'Y2J6YwUDdw', 'trainer_id': 'ZmF6bQUAeQ', 'avisTrainer': 1, 'recordAbs': 729, 'gain': 51310, 'ecurie': nan, 'incident': nan}
# {'nom': 'IVANA DE BERTRANGE', 'numPmu': 4, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 4.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Patrice GENTIL', 'entraineur': 'B. MARIE', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/b-marie/YmFabAUFYA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '7a4m7m2m7a8aDaDa3a3a', 'nombreCourses': 33, 'nombreVictoires': 2, 'nombrePlaces': 21, 'nombrePlacesSecond': 3, 'nombrePlacesTroisieme': 3, 'nomPere': 'AKIM DU CAP VERT', 'nomMere': 'DELIA DE BERTRANGE', 'ordreArrivee': 2.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 150900.0, 'reductionKilometrique': 71900.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P4.png', 'eleveur': 'M. Alain DROUOT', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 5431000, 'gainsParticipant_gainsVictoires': 1395000, 'gainsParticipant_gainsPlace': 4036000, 'gainsParticipant_gainsAnneeEnCours': 3096000, 'gainsParticipant_gainsAnneePrecedente': 2335000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 62.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 4, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 27.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 6.66, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 4, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '4', 'num_tracking': 4, 'distPremArriv': 4, 'reduc2000m': 64800.0, 'class2000m': 1, 'reduc1500m': 67300.0, 'class1500m': 2, 'reduc1000m': 69200.0, 'class1000m': 2, 'reduc500m': 70800.0, 'class500m': 2, 'reducLast1000m': 74500.0, 'reducLast500m': 74700.0, 'numCoursePMU': 'R1C1', 'classement': '2', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ivana-de-bertrange/ZWpbZgMDBQsO/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/b-marie/YmFabAUFYA/entraineur/dernieres-courses', 'driver_id': 'YmFabAUFYA', 'trainer_id': 'YmFabAUFYA', 'avisTrainer': 2, 'recordAbs': 730, 'gain': 54310, 'ecurie': nan, 'incident': nan}
# {'nom': 'INFINITY JET', 'numPmu': 5, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 5.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Mme Sylvie SAINT GEORGES', 'entraineur': 'L. DURANTET', 'deferre': 'PROTEGE_ANTERIEURS_DEFERRRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/l-durantet/ZmB7YQECZg/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '4a0a2a8a1a(21)6a4a5a3a', 'nombreCourses': 11, 'nombreVictoires': 2, 'nombrePlaces': 7, 'nombrePlacesSecond': 2, 'nombrePlacesTroisieme': 1, 'nomPere': 'ROC MESLOIS', 'nomMere': 'VIVOLTA JET', 'ordreArrivee': 12.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 153970.0, 'reductionKilometrique': 73300.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P5.png', 'eleveur': 'M. Pierre Etienne DUBOIS', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 5203000, 'gainsParticipant_gainsVictoires': 2475000, 'gainsParticipant_gainsPlace': 2728000, 'gainsParticipant_gainsAnneeEnCours': 2514000, 'gainsParticipant_gainsAnneePrecedente': 2689000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 9.2, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 5, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 9.1, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 3.52, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 5, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '5', 'num_tracking': 5, 'distPremArriv': 40, 'reduc2000m': 67100.0, 'class2000m': 2, 'reduc1500m': 68600.0, 'class1500m': 7, 'reduc1000m': 70300.0, 'class1000m': 9, 'reduc500m': 72200.0, 'class500m': 13, 'reducLast1000m': 76300.0, 'reducLast500m': 76200.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/infinity-jet/ZWpbZgMBBAYS/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 6, 'firstTimeFer': 1, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/l-durantet/ZmB7YQECZg/entraineur/dernieres-courses', 'driver_id': 'ZmB7YQECZg', 'trainer_id': 'ZmB7YQECZg', 'avisTrainer': 2, 'recordAbs': 730, 'gain': 52030, 'ecurie': nan, 'incident': nan}
# {'nom': 'IDYLLE DE MAHEY', 'numPmu': 6, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 6.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'M. SOULAS', 'entraineur': 'CH. MOTTIER', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/f-lagadeuc/Z2Z6ZwECfA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '3a4aDa1a0a1a1a(21)5a0a', 'nombreCourses': 15, 'nombreVictoires': 4, 'nombrePlaces': 5, 'nombrePlacesSecond': 0, 'nombrePlacesTroisieme': 2, 'nomPere': 'SINGALO', 'nomMere': 'MAHEY STORM', 'ordreArrivee': 9.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 152260.0, 'reductionKilometrique': 72500.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P6.png', 'eleveur': 'M. Michel SOULAS', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 4905000, 'gainsParticipant_gainsVictoires': 3690000, 'gainsParticipant_gainsPlace': 1215000, 'gainsParticipant_gainsAnneeEnCours': 3859000, 'gainsParticipant_gainsAnneePrecedente': 1046000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 4.1, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 6, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 4.7, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '-', 'dernierRapportReference_nombreIndicateurTendance': -9.43, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 6, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '6', 'num_tracking': 6, 'distPremArriv': 21, 'reduc2000m': 72900.0, 'class2000m': 12, 'reduc1500m': 70100.0, 'class1500m': 12, 'reduc1000m': 70500.0, 'class1000m': 11, 'reduc500m': 71400.0, 'class500m': 5, 'reducLast1000m': 74400.0, 'reducLast500m': 75300.0, 'numCoursePMU': 'R1C1', 'classement': '9', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/idylle-de-mahey/ZWpbZQEHAQMZ/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/c-mottier/YGJaYwUFaA/entraineur/dernieres-courses', 'driver_id': 'Z2Z6ZwECfA', 'trainer_id': 'YGJaYwUFaA', 'avisTrainer': 2, 'recordAbs': 747, 'gain': 49050, 'ecurie': nan, 'incident': nan}
# {'nom': 'ISSIA DE CHARLY', 'numPmu': 7, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 7.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'TH. BLOQUET', 'entraineur': 'P. GODEY', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/ph-masschaele/YmZabQUFfw/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '1aDa8a4a0a6a6a3a4a6a', 'nombreCourses': 29, 'nombreVictoires': 2, 'nombrePlaces': 18, 'nombrePlacesSecond': 1, 'nombrePlacesTroisieme': 6, 'nomPere': 'CHARLY DU NOYER', 'nomMere': 'TISSIA DES TOUCHES', 'ordreArrivee': 1.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 150490.0, 'reductionKilometrique': 71700.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P7.png', 'eleveur': 'M. Thierry BLOQUET', 'allure': 'TROT', 'avisEntraineur': 'NEGATIF', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 4823000, 'gainsParticipant_gainsVictoires': 2025000, 'gainsParticipant_gainsPlace': 2798000, 'gainsParticipant_gainsAnneeEnCours': 2472000, 'gainsParticipant_gainsAnneePrecedente': 2351000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 19.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 7, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 20.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 2.95, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 7, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '7', 'num_tracking': 7, 'distPremArriv': 0, 'reduc2000m': 69000.0, 'class2000m': 5, 'reduc1500m': 66800.0, 'class1500m': 1, 'reduc1000m': 68900.0, 'class1000m': 1, 'reduc500m': 70500.0, 'class500m': 1, 'reducLast1000m': 74400.0, 'reducLast500m': 74600.0, 'numCoursePMU': 'R1C1', 'classement': '1', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/issia-de-charly/ZWpbZQMICgQF/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/p-godey/YGNbZAIAeQ/entraineur/dernieres-courses', 'driver_id': 'YmZabQUFfw', 'trainer_id': 'YGNbZAIAeQ', 'avisTrainer': 3, 'recordAbs': 728, 'gain': 48230, 'ecurie': nan, 'incident': nan}
# {'nom': 'INAYA MATIDY', 'numPmu': 8, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 8.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Cédric POSTOLLEC', 'entraineur': 'T. LE BELLER', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/y-lebourgeois/YmJaZQoDcA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': 'DaDa1a4a0a(21)7aDaDaDa', 'nombreCourses': 16, 'nombreVictoires': 4, 'nombrePlaces': 4, 'nombrePlacesSecond': 1, 'nombrePlacesTroisieme': 0, 'nomPere': 'URIEL SPEED', 'nomMere': 'VIRGIN JET', 'ordreArrivee': 11.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 152860.0, 'reductionKilometrique': 72800.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P8.png', 'eleveur': 'Mme Cécilia * LEFEBVRE', 'allure': 'TROT', 'avisEntraineur': 'POSITIF', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 5026000, 'gainsParticipant_gainsVictoires': 4050000, 'gainsParticipant_gainsPlace': 976000, 'gainsParticipant_gainsAnneeEnCours': 1077000, 'gainsParticipant_gainsAnneePrecedente': 3949000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 5.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 8, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 8.7, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 5.95, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 8, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '8', 'num_tracking': 8, 'distPremArriv': 27, 'reduc2000m': 67700.0, 'class2000m': 4, 'reduc1500m': 68400.0, 'class1500m': 5, 'reduc1000m': 69800.0, 'class1000m': 4, 'reduc500m': 71300.0, 'class500m': 4, 'reducLast1000m': 75600.0, 'reducLast500m': 76700.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/inaya-matidy/ZWpbZgoJBgUN/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/t-le-beller/YWd4YgMGZA/entraineur/dernieres-courses', 'driver_id': 'YmJaZQoDcA', 'trainer_id': 'YWd4YgMGZA', 'avisTrainer': 1, 'recordAbs': 732, 'gain': 50260, 'ecurie': nan, 'incident': nan}
# {'nom': 'IRINUSHKA', 'numPmu': 9, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 9.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Mme M. STIHL', 'entraineur': 'F. SENET', 'deferre': 'PROTEGE_ANTERIEURS_DEFERRRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/f-senet/bGV5ZwMBfw/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '4aDm9a4a0m6a5mDa5m', 'nombreCourses': 31, 'nombreVictoires': 0, 'nombrePlaces': 21, 'nombrePlacesSecond': 2, 'nombrePlacesTroisieme': 3, 'nomPere': 'BIRD PARKER', 'nomMere': 'DUNYASHA', 'ordreArrivee': 15.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 157070.0, 'reductionKilometrique': 74800.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P9.png', 'eleveur': 'M. Jean-Pierre DUBOIS', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 5343000, 'gainsParticipant_gainsVictoires': 0, 'gainsParticipant_gainsPlace': 5343000, 'gainsParticipant_gainsAnneeEnCours': 1184000, 'gainsParticipant_gainsAnneePrecedente': 2515000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 138.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 9, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 53.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 5.27, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 9, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '9', 'num_tracking': 9, 'distPremArriv': 73, 'reduc2000m': 69500.0, 'class2000m': 6, 'reduc1500m': 68000.0, 'class1500m': 4, 'reduc1000m': 70100.0, 'class1000m': 7, 'reduc500m': 71900.0, 'class500m': 11, 'reducLast1000m': 79600.0, 'reducLast500m': 83300.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/irinushka/ZWpbZQMDCgIF/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 6, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/f-senet/bGV5ZwMBfw/entraineur/dernieres-courses', 'driver_id': 'bGV5ZwMBfw', 'trainer_id': 'bGV5ZwMBfw', 'avisTrainer': 2, 'recordAbs': 734, 'gain': 53430, 'ecurie': nan, 'incident': nan}
# {'nom': 'IRMA DU VIVIER', 'numPmu': 10, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 10.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie MINIER', 'entraineur': 'B. ROBIN', 'deferre': 'PROTEGE_ANTERIEURS_DEFERRRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/b-robin/YGJaZwQFZA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '6a1a5a2a2a6aDa7a4a', 'nombreCourses': 16, 'nombreVictoires': 2, 'nombrePlaces': 12, 'nombrePlacesSecond': 3, 'nombrePlacesTroisieme': 0, 'nomPere': "UN MEC D'HERIPRE", 'nomMere': 'DAIRA DU VIVIER', 'ordreArrivee': 3.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 151150.0, 'reductionKilometrique': 72000.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P10.png', 'eleveur': 'Ecurie Jean Yves LECUYER', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '021', 'robe_libelleCourt': 'BAI F.', 'robe_libelleLong': 'BAI FONCE', 'gainsParticipant_gainsCarriere': 4797000, 'gainsParticipant_gainsVictoires': 2070000, 'gainsParticipant_gainsPlace': 2727000, 'gainsParticipant_gainsAnneeEnCours': 3405000, 'gainsParticipant_gainsAnneePrecedente': 1392000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 29.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 10, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 21.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 4.41, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 10, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '10', 'num_tracking': 10, 'distPremArriv': 8, 'reduc2000m': 73200.0, 'class2000m': 10, 'reduc1500m': 68500.0, 'class1500m': 6, 'reduc1000m': 69900.0, 'class1000m': 5, 'reduc500m': 71500.0, 'class500m': 6, 'reducLast1000m': 73900.0, 'reducLast500m': 72900.0, 'numCoursePMU': 'R1C1', 'classement': '3', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/irma-du-vivier/ZWpbZQIIAwIf/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 6, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/b-robin/YGJaZwQFZA/entraineur/dernieres-courses', 'driver_id': 'YGJaZwQFZA', 'trainer_id': 'YGJaZwQFZA', 'avisTrainer': 2, 'recordAbs': 733, 'gain': 47970, 'ecurie': nan, 'incident': nan}
# {'nom': 'IPANEMA DE LOU', 'numPmu': 11, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 11.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'CH. GERMAIN', 'entraineur': 'L.CL. ABRIVARD', 'deferre': 'DEFERRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/lcl-abrivard/ZGJbZgEAfw/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': 'Da7a8a7a3a2a1a4a(21)7a', 'nombreCourses': 11, 'nombreVictoires': 2, 'nombrePlaces': 7, 'nombrePlacesSecond': 2, 'nombrePlacesTroisieme': 1, 'nomPere': 'SAM BOURBON', 'nomMere': 'SELECAO DE LOU', 'ordreArrivee': 8.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 152140.0, 'reductionKilometrique': 72400.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P11.png', 'eleveur': 'M. Christian GERMAIN', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 3825000, 'gainsParticipant_gainsVictoires': 2070000, 'gainsParticipant_gainsPlace': 1755000, 'gainsParticipant_gainsAnneeEnCours': 2736000, 'gainsParticipant_gainsAnneePrecedente': 1089000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 80.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 11, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 37.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 3.74, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 11, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '11', 'num_tracking': 11, 'distPremArriv': 9999, 'reduc2000m': 73200.0, 'class2000m': 11, 'reduc1500m': 69600.0, 'class1500m': 11, 'reduc1000m': 70400.0, 'class1000m': 10, 'reduc500m': 639900.0, 'class500m': 9999, 'reducLast1000m': 639900.0, 'reducLast500m': 639900.0, 'numCoursePMU': 'R1C1', 'classement': '8', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ipanema-de-lou/ZWpbZAsEBAUM/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 2, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/lc-abrivard/ZGJbZgEAfw/entraineur/dernieres-courses', 'driver_id': 'ZGJbZgEAfw', 'trainer_id': 'ZGJbZgEAfw', 'avisTrainer': 2, 'recordAbs': 725, 'gain': 38250, 'ecurie': nan, 'incident': nan}
# {'nom': 'ILE DESERTE', 'numPmu': 12, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 12.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie Jean-Pierre BARJON', 'entraineur': 'L.CL. ABRIVARD', 'deferre': 'DEFERRE_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/a-abrivard/ZGtaZAQCdA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '3aDa4aDa1a0a(21)5a3a5a', 'nombreCourses': 14, 'nombreVictoires': 3, 'nombrePlaces': 5, 'nombrePlacesSecond': 0, 'nombrePlacesTroisieme': 2, 'nomPere': 'OISEAU DE FEUX', 'nomMere': 'UGENIE DU CITRUS', 'ordreArrivee': 16.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 181040.0, 'reductionKilometrique': 86200.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P12.png', 'eleveur': 'Ecurie Jean-Pierre BARJON', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '001', 'robe_libelleCourt': 'ALEZAN', 'robe_libelleLong': 'ALEZAN', 'gainsParticipant_gainsCarriere': 4539000, 'gainsParticipant_gainsVictoires': 3195000, 'gainsParticipant_gainsPlace': 1344000, 'gainsParticipant_gainsAnneeEnCours': 2403000, 'gainsParticipant_gainsAnneePrecedente': 2136000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 20.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 12, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 20.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 5.02, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 12, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '12', 'num_tracking': 12, 'distPremArriv': 246, 'reduc2000m': 71900.0, 'class2000m': 9, 'reduc1500m': 69100.0, 'class1500m': 9, 'reduc1000m': 70000.0, 'class1000m': 6, 'reduc500m': 72600.0, 'class500m': 15, 'reducLast1000m': 103700.0, 'reducLast500m': 129100.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/ile-deserte/ZWpbZQMFBAMD/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 2, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/lc-abrivard/ZGJbZgEAfw/entraineur/dernieres-courses', 'driver_id': 'ZGtaZAQCdA', 'trainer_id': 'ZGJbZgEAfw', 'avisTrainer': 2, 'recordAbs': 736, 'gain': 45390, 'ecurie': nan, 'incident': nan}
# {'nom': 'INIDILLE', 'numPmu': 13, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 13.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie LUCKY 8 RACING', 'entraineur': 'D. LOCQUENEUX', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/d-locqueneux/YWt4YwIFZA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': 'Da2a1a8a1a5aDa2a(21)5a', 'nombreCourses': 11, 'nombreVictoires': 2, 'nombrePlaces': 6, 'nombrePlacesSecond': 3, 'nombrePlacesTroisieme': 0, 'nomPere': 'REX NORMANUS', 'nomMere': 'VENIDILLE', 'ordreArrivee': 10.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 152620.0, 'reductionKilometrique': 72700.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P13.png', 'eleveur': 'M. Paul VIEL', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 3318000, 'gainsParticipant_gainsVictoires': 1665000, 'gainsParticipant_gainsPlace': 1653000, 'gainsParticipant_gainsAnneeEnCours': 2825000, 'gainsParticipant_gainsAnneePrecedente': 493000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 43.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 13, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 32.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 4.56, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 13, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '13', 'num_tracking': 13, 'distPremArriv': 28, 'reduc2000m': 76100.0, 'class2000m': 13, 'reduc1500m': 70200.0, 'class1500m': 13, 'reduc1000m': 70800.0, 'class1000m': 13, 'reduc500m': 72100.0, 'class500m': 12, 'reducLast1000m': 74400.0, 'reducLast500m': 73900.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/inidille/ZWpbYQEIAQUA/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/d-locqueneux/YWt4YwIFZA/entraineur/dernieres-courses', 'driver_id': 'YWt4YwIFZA', 'trainer_id': 'YWt4YwIFZA', 'avisTrainer': 2, 'recordAbs': 740, 'gain': 33180, 'ecurie': nan, 'incident': nan}
# {'nom': 'IMAGE CHARENTAISE', 'numPmu': 14, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 14.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie Régis MAURICE', 'entraineur': 'F. LEBLANC', 'deferre': nan, 'driver': 'https://www.letrot.com/stats/fiche-homme/h-mornet/YGN9YAcDdA/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': 'Da3a8aDaDa(21)3a0a5a3a', 'nombreCourses': 21, 'nombreVictoires': 2, 'nombrePlaces': 10, 'nombrePlacesSecond': 0, 'nombrePlacesTroisieme': 3, 'nomPere': "CANADIEN D'AM", 'nomMere': 'BLOUETTE DARLING', 'ordreArrivee': 14.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 156650.0, 'reductionKilometrique': 74600.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P14.png', 'eleveur': 'Ecurie Régis MAURICE', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 4531000, 'gainsParticipant_gainsVictoires': 1980000, 'gainsParticipant_gainsPlace': 2551000, 'gainsParticipant_gainsAnneeEnCours': 546000, 'gainsParticipant_gainsAnneePrecedente': 3963000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 180.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 14, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 104.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 6.83, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 14, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '14', 'num_tracking': 14, 'distPremArriv': 71, 'reduc2000m': 78500.0, 'class2000m': 15, 'reduc1500m': 70700.0, 'class1500m': 14, 'reduc1000m': 71200.0, 'class1000m': 15, 'reduc500m': 72500.0, 'class500m': 14, 'reducLast1000m': 78100.0, 'reducLast500m': 80900.0, 'numCoursePMU': 'R1C1', 'classement': '0', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/image-charentaise/ZWpbZgYFAAIc/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 0, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/f-leblanc/YWd3ZAsFaA/entraineur/dernieres-courses', 'driver_id': 'YGN9YAcDdA', 'trainer_id': 'YWd3ZAsFaA', 'avisTrainer': 2, 'recordAbs': 738, 'gain': 45310, 'ecurie': nan, 'incident': nan}
# {'nom': "INDIANA D'ESPACE", 'numPmu': 15, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 15.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'Ecurie EN AVANT GOUDIG', 'entraineur': 'A. GARANDEAU', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/e-raffin/Y2t9ZQIAZQ/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '8m2a2a4a6a7a2a6a2a8a', 'nombreCourses': 32, 'nombreVictoires': 0, 'nombrePlaces': 23, 'nombrePlacesSecond': 7, 'nombrePlacesTroisieme': 3, 'nomPere': 'QUINOA DU GERS', 'nomMere': 'VINESA', 'ordreArrivee': 4.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 151370.0, 'reductionKilometrique': 72100.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P15.png', 'eleveur': 'E.A.R.L. FEUILLET', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 4746000, 'gainsParticipant_gainsVictoires': 0, 'gainsParticipant_gainsPlace': 4746000, 'gainsParticipant_gainsAnneeEnCours': 2042000, 'gainsParticipant_gainsAnneePrecedente': 2654000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 21.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 15, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 15.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 0.63, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 15, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '15', 'num_tracking': 15, 'distPremArriv': 11, 'reduc2000m': 76500.0, 'class2000m': 14, 'reduc1500m': 70700.0, 'class1500m': 15, 'reduc1000m': 71100.0, 'class1000m': 14, 'reduc500m': 71600.0, 'class500m': 8, 'reducLast1000m': 72800.0, 'reducLast500m': 72800.0, 'numCoursePMU': 'R1C1', 'classement': '4', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/indiana-despace/ZWpbZQcBAAYD/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 0, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/a-garandeau/YWd9ZQECdA/entraineur/dernieres-courses', 'driver_id': 'Y2t9ZQIAZQ', 'trainer_id': 'YWd9ZQECdA', 'avisTrainer': 2, 'recordAbs': 738, 'gain': 47460, 'ecurie': nan, 'incident': nan}
# {'nom': 'INDESKAYA BIRD', 'numPmu': 16, 'age': 4, 'sexe': 'FEMELLES', 'race': 'TROTTEUR FRANCAIS', 'statut': 'PARTANT', 'placeCorde': 16.0, 'oeilleres': 'SANS_OEILLERES', 'proprietaire': 'ED. COUBARD-MEUNIER', 'entraineur': 'ED. COUBARD-MEUNIER', 'deferre': 'DEFERRE_ANTERIEURS_POSTERIEURS', 'driver': 'https://www.letrot.com/stats/fiche-homme/ed-coubard-meunier/bGt2bAcEag/jockey/dernieres-courses', 'driverChange': False, 'indicateurInedit': False, 'musique': '8a8a3a5a3a4a0a1aDa', 'nombreCourses': 16, 'nombreVictoires': 2, 'nombrePlaces': 10, 'nombrePlacesSecond': 0, 'nombrePlacesTroisieme': 5, 'nomPere': 'SCIPION DU GOUTIER', 'nomMere': 'BARVA', 'ordreArrivee': 6.0, 'jumentPleine': False, 'engagement': False, 'supplement': 0, 'handicapDistance': 2100, 'poidsConditionMonteChange': False, 'tempsObtenu': 151830.0, 'reductionKilometrique': 72300.0, 'urlCasaque': 'https://www.pmu.fr/back-assets/hippique/casaques/16092022/R1/C1/P16.png', 'eleveur': 'M. Pascal RIGOLLE', 'allure': 'TROT', 'avisEntraineur': 'NEUTRE', 'robe_code': '020', 'robe_libelleCourt': 'BAI', 'robe_libelleLong': 'BAI', 'gainsParticipant_gainsCarriere': 3379000, 'gainsParticipant_gainsVictoires': 1530000, 'gainsParticipant_gainsPlace': 1849000, 'gainsParticipant_gainsAnneeEnCours': 1737000, 'gainsParticipant_gainsAnneePrecedente': 1642000, 'dernierRapportDirect_typePari': 'SIMPLE_GAGNANT', 'dernierRapportDirect_rapport': 79.0, 'dernierRapportDirect_typeRapport': 'DIRECT', 'dernierRapportDirect_indicateurTendance': ' ', 'dernierRapportDirect_nombreIndicateurTendance': 0.0, 'dernierRapportDirect_dateRapport': 1663347573000, 'dernierRapportDirect_permutation': 1, 'dernierRapportDirect_favoris': False, 'dernierRapportDirect_numPmu1': 16, 'dernierRapportDirect_grossePrise': False, 'dernierRapportReference_typePari': 'SIMPLE_GAGNANT', 'dernierRapportReference_rapport': 37.0, 'dernierRapportReference_typeRapport': 'REFERENCE', 'dernierRapportReference_indicateurTendance': '+', 'dernierRapportReference_nombreIndicateurTendance': 5.93, 'dernierRapportReference_dateRapport': 1663345685000, 'dernierRapportReference_permutation': 1, 'dernierRapportReference_favoris': False, 'dernierRapportReference_numPmu1': 16, 'dernierRapportReference_grossePrise': False, 'id': 2022091675001, 'numReunion': 1, 'num': '16', 'num_tracking': 16, 'distPremArriv': 17, 'reduc2000m': 78900.0, 'class2000m': 16, 'reduc1500m': 71300.0, 'class1500m': 16, 'reduc1000m': 71400.0, 'class1000m': 16, 'reduc500m': 71800.0, 'class500m': 10, 'reducLast1000m': 73000.0, 'reducLast500m': 73100.0, 'numCoursePMU': 'R1C1', 'classement': '6', 'date': '2022-09-16', 'url': 'https://www.letrot.com/stats/fiche-cheval/indeskaya-bird/ZWpbZQQFAAIQ/courses/dernieres-performances', 'heureCourse': '18:58', 'fer': 3, 'firstTimeFer': 1, 'sex': 1, 'dist': 2100, 'trainer': 'https://www.letrot.com/stats/fiche-homme/e-coubard-meunier/bGt2bAcEag/entraineur/dernieres-courses', 'driver_id': 'bGt2bAcEag', 'trainer_id': 'bGt2bAcEag', 'avisTrainer': 2, 'recordAbs': 742, 'gain': 33790, 'ecurie': nan, 'incident': nan}

# %%
courses[courses["id"] == 2022091675001].to_dict("records")
# Out:
# [{'date': Timestamp('2022-09-16 18:58:00'),
#   'id': 2022091675001,
#   'numReunion': 1,
#   'hippodrome': 'VINCENNES',
#   'idHippo': 7500,
#   'heureCourse': '18:58',
#   'discipline': 'Attelé',
#   'numCourse': 1,
#   'prix': 'PRIX LUCRETIA',
#   'allocation': '39 000',
#   'distance': 2100,
#   'categorie': 'Course D',
#   'typePiste': nan,
#   'conditionsEngagement': "Départ à l'autostart<br />Pour pouliches de 4 ans, n'ayant pas gagné 55.000.<br />",
#   'hasTracking': True,
#   'hasVideoHeat': False,
#   'statut': 16,
#   'classement': '7 - 4 - 10 - 15 - 3',
#   'linkPrix': 'https://www.letrot.com/stats/fiche-course/2022-09-16/7500/1/resultats/arrivee-definitive',
#   'replay': '<a href="https://www.letrot.com/fr/replay-courses/2022-09-16/7500/1" class="btn" target="_blank"><svg width="8px" height="12px" viewBox="0 0 8 12" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="Page-1" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><polygon id="triangle" fill="#ffffff" transform="translate(4.000000, 6.000000) rotate(90.000000) translate(-4.000000, -6.000000) " points="4 2 10 10 -2 10"></polygon></g></svg>Voir le replay</a>'}]

# %%
df[df["id"] == 2022091675001]
# Out:
#                    nom  numPmu  age      sexe               race   statut  \
# 0         INES PICARDE       1    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 1    INES DE LA ROUVRE       2    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 2            ICE QUICK       3    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 3   IVANA DE BERTRANGE       4    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 4         INFINITY JET       5    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 5      IDYLLE DE MAHEY       6    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 6      ISSIA DE CHARLY       7    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 7         INAYA MATIDY       8    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 8            IRINUSHKA       9    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 9       IRMA DU VIVIER      10    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 10      IPANEMA DE LOU      11    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 11         ILE DESERTE      12    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 12            INIDILLE      13    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 13   IMAGE CHARENTAISE      14    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 14    INDIANA D'ESPACE      15    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
# 15      INDESKAYA BIRD      16    4  FEMELLES  TROTTEUR FRANCAIS  PARTANT
#
#     placeCorde       oeilleres               proprietaire  \
# 0          1.0  SANS_OEILLERES          Ecurie J-F. SENET
# 1          2.0  SANS_OEILLERES          Ecurie L.M. DAVID
# 2          3.0  SANS_OEILLERES          Ecurie QUICK STAR
# 3          4.0  SANS_OEILLERES             Patrice GENTIL
# 4          5.0  SANS_OEILLERES   Mme Sylvie SAINT GEORGES
# 5          6.0  SANS_OEILLERES                  M. SOULAS
# 6          7.0  SANS_OEILLERES                TH. BLOQUET
# 7          8.0  SANS_OEILLERES           Cédric POSTOLLEC
# 8          9.0  SANS_OEILLERES               Mme M. STIHL
# 9         10.0  SANS_OEILLERES              Ecurie MINIER
# 10        11.0  SANS_OEILLERES                CH. GERMAIN
# 11        12.0  SANS_OEILLERES  Ecurie Jean-Pierre BARJON
# 12        13.0  SANS_OEILLERES      Ecurie LUCKY 8 RACING
# 13        14.0  SANS_OEILLERES       Ecurie Régis MAURICE
# 14        15.0  SANS_OEILLERES     Ecurie EN AVANT GOUDIG
# 15        16.0  SANS_OEILLERES        ED. COUBARD-MEUNIER
#
#              entraineur  ... sex  dist  \
# 0            J.F. SENET  ...   1  2100
# 1            L.M. DAVID  ...   1  2100
# 2          P.J. CORDEAU  ...   1  2100
# 3              B. MARIE  ...   1  2100
# 4           L. DURANTET  ...   1  2100
# 5           CH. MOTTIER  ...   1  2100
# 6              P. GODEY  ...   1  2100
# 7          T. LE BELLER  ...   1  2100
# 8              F. SENET  ...   1  2100
# 9              B. ROBIN  ...   1  2100
# 10       L.CL. ABRIVARD  ...   1  2100
# 11       L.CL. ABRIVARD  ...   1  2100
# 12        D. LOCQUENEUX  ...   1  2100
# 13           F. LEBLANC  ...   1  2100
# 14         A. GARANDEAU  ...   1  2100
# 15  ED. COUBARD-MEUNIER  ...   1  2100
#
#                                               trainer   driver_id  trainer_id  \
# 0   https://www.letrot.com/stats/fiche-homme/jf-se...  bGV5ZwMDeQ  bGV5ZwMDeQ
# 1   https://www.letrot.com/stats/fiche-homme/lm-da...  ZmRaYwYFdA  ZmRaYwYFdA
# 2   https://www.letrot.com/stats/fiche-homme/pj-co...  Y2J6YwUDdw  ZmF6bQUAeQ
# 3   https://www.letrot.com/stats/fiche-homme/b-mar...  YmFabAUFYA  YmFabAUFYA
# 4   https://www.letrot.com/stats/fiche-homme/l-dur...  ZmB7YQECZg  ZmB7YQECZg
# 5   https://www.letrot.com/stats/fiche-homme/c-mot...  Z2Z6ZwECfA  YGJaYwUFaA
# 6   https://www.letrot.com/stats/fiche-homme/p-god...  YmZabQUFfw  YGNbZAIAeQ
# 7   https://www.letrot.com/stats/fiche-homme/t-le-...  YmJaZQoDcA  YWd4YgMGZA
# 8   https://www.letrot.com/stats/fiche-homme/f-sen...  bGV5ZwMBfw  bGV5ZwMBfw
# 9   https://www.letrot.com/stats/fiche-homme/b-rob...  YGJaZwQFZA  YGJaZwQFZA
# 10  https://www.letrot.com/stats/fiche-homme/lc-ab...  ZGJbZgEAfw  ZGJbZgEAfw
# 11  https://www.letrot.com/stats/fiche-homme/lc-ab...  ZGtaZAQCdA  ZGJbZgEAfw
# 12  https://www.letrot.com/stats/fiche-homme/d-loc...  YWt4YwIFZA  YWt4YwIFZA
# 13  https://www.letrot.com/stats/fiche-homme/f-leb...  YGN9YAcDdA  YWd3ZAsFaA
# 14  https://www.letrot.com/stats/fiche-homme/a-gar...  Y2t9ZQIAZQ  YWd9ZQECdA
# 15  https://www.letrot.com/stats/fiche-homme/e-cou...  bGt2bAcEag  bGt2bAcEag
#
#     avisTrainer  recordAbs   gain  ecurie  incident
# 0             2        725  48800     NaN       NaN
# 1             1        731  48680     NaN       NaN
# 2             1        729  51310     NaN       NaN
# 3             2        730  54310     NaN       NaN
# 4             2        730  52030     NaN       NaN
# 5             2        747  49050     NaN       NaN
# 6             3        728  48230     NaN       NaN
# 7             1        732  50260     NaN       NaN
# 8             2        734  53430     NaN       NaN
# 9             2        733  47970     NaN       NaN
# 10            2        725  38250     NaN       NaN
# 11            2        736  45390     NaN       NaN
# 12            2        740  33180     NaN       NaN
# 13            2        738  45310     NaN       NaN
# 14            2        738  47460     NaN       NaN
# 15            2        742  33790     NaN       NaN
#
# [16 rows x 94 columns]

# %%
for i in df.dtypes.items():
    t = str(i[1]).replace("object", "TEXT").replace("int64", "INT").replace("float64", "FLOAT").replace("bool", "BOOLEAN")
    print(i[0],"=", f"Column({t})")
# Out:
# nom = Column(TEXT)
# numPmu = Column(INT)
# age = Column(INT)
# sexe = Column(TEXT)
# race = Column(TEXT)
# statut = Column(TEXT)
# placeCorde = Column(FLOAT)
# oeilleres = Column(TEXT)
# proprietaire = Column(TEXT)
# entraineur = Column(TEXT)
# driver = Column(TEXT)
# driverChange = Column(BOOLEAN)
# indicateurInedit = Column(BOOLEAN)
# musique = Column(TEXT)
# nombreCourses = Column(INT)
# nombreVictoires = Column(INT)
# nombrePlaces = Column(INT)
# nomPere = Column(TEXT)
# nomMere = Column(TEXT)
# ordreArrivee = Column(FLOAT)
# jumentPleine = Column(BOOLEAN)
# engagement = Column(BOOLEAN)
# supplement = Column(INT)
# handicapDistance = Column(INT)
# poidsConditionMonteChange = Column(BOOLEAN)
# tempsObtenu = Column(FLOAT)
# reductionKilometrique = Column(FLOAT)
# allure = Column(TEXT)
# robe_code = Column(TEXT)
# robe_libelleCourt = Column(TEXT)
# robe_libelleLong = Column(TEXT)
# dernierRapportDirect_typePari = Column(TEXT)
# dernierRapportDirect_rapport = Column(FLOAT)
# dernierRapportDirect_typeRapport = Column(TEXT)
# dernierRapportDirect_indicateurTendance = Column(TEXT)
# dernierRapportDirect_nombreIndicateurTendance = Column(FLOAT)
# dernierRapportDirect_dateRapport = Column(FLOAT)
# dernierRapportDirect_permutation = Column(FLOAT)
# dernierRapportDirect_favoris = Column(TEXT)
# dernierRapportDirect_numPmu1 = Column(FLOAT)
# dernierRapportDirect_grossePrise = Column(TEXT)
# deferre = Column(TEXT)
# dernierRapportReference_typePari = Column(TEXT)
# dernierRapportReference_rapport = Column(FLOAT)
# dernierRapportReference_typeRapport = Column(TEXT)
# dernierRapportReference_indicateurTendance = Column(TEXT)
# dernierRapportReference_nombreIndicateurTendance = Column(FLOAT)
# dernierRapportReference_dateRapport = Column(FLOAT)
# dernierRapportReference_permutation = Column(FLOAT)
# dernierRapportReference_favoris = Column(TEXT)
# dernierRapportReference_numPmu1 = Column(FLOAT)
# dernierRapportReference_grossePrise = Column(TEXT)
# incident = Column(TEXT)
# numReunion = Column(INT)
# num = Column(TEXT)
# numCoursePMU = Column(TEXT)
# classement = Column(TEXT)
# date = Column(TEXT)
# url = Column(TEXT)
# heureCourse = Column(TEXT)
# fer = Column(INT)
# firstTimeFer = Column(INT)
# sex = Column(INT)
# dist = Column(INT)
# trainer = Column(TEXT)
# driver_id = Column(TEXT)
# trainer_id = Column(TEXT)
# avisTrainer = Column(INT)
# recordAbs = Column(FLOAT)
# gain = Column(INT)
# rid = Column(INT)
# ecurie = Column(TEXT)
# urlCasaque = Column(TEXT)
# nombrePlacesSecond = Column(FLOAT)
# nombrePlacesTroisieme = Column(FLOAT)
# eleveur = Column(TEXT)
# avisEntraineur = Column(TEXT)
# gainsParticipant_gainsCarriere = Column(FLOAT)
# gainsParticipant_gainsVictoires = Column(FLOAT)
# gainsParticipant_gainsPlace = Column(FLOAT)
# gainsParticipant_gainsAnneeEnCours = Column(FLOAT)
# gainsParticipant_gainsAnneePrecedente = Column(FLOAT)
# poidsConditionMonte = Column(FLOAT)
# num_tracking = Column(FLOAT)
# distPremArriv = Column(FLOAT)
# reduc2000m = Column(FLOAT)
# class2000m = Column(FLOAT)
# reduc1500m = Column(FLOAT)
# class1500m = Column(FLOAT)
# reduc1000m = Column(FLOAT)
# class1000m = Column(FLOAT)
# reduc500m = Column(FLOAT)
# class500m = Column(FLOAT)
# reducLast1000m = Column(FLOAT)
# reducLast500m = Column(FLOAT)
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=TypeError("'NoneType' object is not iterable")>
# Traceback (most recent call last):
#   File "C:\Users\raves\anaconda3\lib\asyncio\tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "<ipython-input-504-2bfb74fc93d6>", line 152, in _info_tableau_partant
#     chevaux.extend(tableau_pmu)
# TypeError: 'NoneType' object is not iterable
